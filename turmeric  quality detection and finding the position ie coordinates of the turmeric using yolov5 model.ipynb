# %% [markdown]
# # **Turmeric Size and Position Detection AI and Robotics Project**

# %%
# Step 1: Clone YOLOv5 and Install Dependencies
# !git clone https://github.com/ultralytics/yolov5  # Clone YOLOv5 repository
# %cd yolov5
# !pip install -qr requirements.txt  # Install the required Python packages

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-317-g00403794 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.0/78.2 GB disk)

# %%
# Import essential packages
import torch
from IPython.display import display
import os
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw, ImageFont
import numpy as np
import shutil
import glob

# %%
# %cd
# Out:
# /root

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)


# Assuming your zip file is located in the root of your Google Drive and is named 'your-zip-file.zip'
# Modify the path below according to the actual path of your zip file
zip_file_path = '/content/drive/My Drive/turmeric_dataset_mix.zip'

# Destination folder where you want to extract the zip files
# You can change this directory according to where you need the files
extraction_directory = '/content/unzipped_files'

# Create the directory if it does not exist
import os
if not os.path.exists(extraction_directory):
    os.makedirs(extraction_directory)

# Command to unzip the file
# !unzip -uq "$zip_file_path" -d "$extraction_directory"
# Out:
# Mounted at /content/drive

# %%
# Step 5: Train the Model for the Normal dataset
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 32  --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache --project /content/drive/MyDrive/turmeric_training --name yolov5s_results

# Train code for the mix dataset.
# %%time
# %cd /content/yolov5/
# !python train.py --img 640 --batch 32  --epochs 200 --data custom_data.yaml --weights yolov5s.pt --cache --project /content/drive/MyDrive/turmeric_training_mix --name yolov5s_results
# Out:
# /content/yolov5
# 2024-05-29 07:07:43.527344: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-29 07:07:43.527401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-29 07:07:43.529397: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# # Step 6: Load Trained Model and Validate
# model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/drive/MyDrive/turmeric_training/yolov5s_results/weights/best.pt', force_reload=True)

# %%
# %cd /content/yolov5/
# !python detect.py
# Out:
# /content/yolov5
# requirements: /usr/local/lib/python3.10/dist-packages/requirements.txt not found, check failed.
# detect: weights=best.pt, source=data/images, data=data/custom_data.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-315-g892e8a82 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/10 /content/yolov5/data/images/IMG20240504120310.jpg: 480x640 Done. (48.1ms)
# image 2/10 /content/yolov5/data/images/IMG20240504120320.jpg: 480x640 Done. (9.0ms)
# ...

# %% [markdown]
# **For Visualizing the Bounding Boxes and the Coordinates of the each turmeric**

# %% [markdown]
# #For validating the Videos if we want to validate by using video source which we need to upload and then run the below code and get the result.

# %%
# %cd /content/yolov5/
# !python detect.py --weights /content/yolov5/best.pt --img 640 --conf 0.35 --source ../MIx_VID2.mp4
# Out:
# /content/yolov5
# detect: weights=['/content/yolov5/best.pt'], source=../MIx_VID2.mp4, data=data/custom_data.yaml, imgsz=[640, 640], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /usr/local/lib/python3.10/dist-packages/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-314-g60dde7f1 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Speed: 1.1ms pre-process, 300.8ms inference, 0.9ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp6
